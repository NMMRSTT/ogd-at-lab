# %% [markdown]
# # Accessing Different Types of Webservices
#
# [![Binder](http://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/anitagraser/ogd-at-lab/main?urlpath=lab/tree/notebooks/webmapping.ipynb)

# %% [markdown]
# ## 1. Basemap tiles (XYZ tiles)
#
# Documentation:  http://geoviews.org/user_guide/Working_with_Bokeh.html

# %%
import holoviews as hv
import geoviews as gv
gv.extension('bokeh')

basemap = hv.element.tiles.OSM().opts(width=450, height=450)
basemap
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1009'>
#   <div id="ba4bb7dc-5e6c-452e-bda8-8ba822ae63f3" data-root-id="p1009" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ff4c6601-feb2-4bd5-aa87-49000ed34401":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1009"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1010","attributes":{"plot_id":"p1009","comm_id":"2d83ee76e3ec4415b744ab43dd8dc287","client_comm_id":"222be66663d6441c9591093b951c320e"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"ff4c6601-feb2-4bd5-aa87-49000ed34401","roots":{"p1009":"ba4bb7dc-5e6c-452e-bda8-8ba822ae63f3"},"root_ids":["p1009"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Tiles   [x,y]

# %% [markdown]
# ## 2. Web Map Services (WMS)
# Source: https://github.com/holoviz/geoviews/issues/481

# %%
def load_wms(server="http://data.wien.gv.at/daten/geo", layer="ogdwien:DONAUINSPKTOGD", extents=(1825290,6144246,1827693,6146435)):
    url = f"{server}?&service=WMS&request=GetMap&layers={layer}&styles=&format=image/png&transparent=true&version=1.3.0&width=256&height=256&crs=EPSG:3857"
    url = url + "&bbox={XMIN},{YMIN},{XMAX},{YMAX}"
    return hv.Tiles(url, extents=extents)

# %%
map_with_overlay = basemap * load_wms()
map_with_overlay
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Tiles.II :Tiles   [x,y]

# %%
map_with_overlay * load_wms(layer="ogdwien:DONAUKILOMETEROGD")
# Out:
# :Overlay
#    .Tiles.I   :Tiles   [x,y]
#    .Tiles.II  :Tiles   [x,y]
#    .Tiles.III :Tiles   [x,y]

# %% [markdown]
# ### 3. Web Feature Services (WFS)

# %%
import geopandas as gpd
from urllib.request import urlretrieve
import hvplot.pandas

layer = 'RADGRAETZELOGD'
file = f'data/{layer}.json'
url = f"https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:{layer}&srsName=EPSG:4326&outputFormat=json"
urlretrieve(url, file)
gdf = gpd.read_file(file)
gdf
# Out:
#                       id  OBJECTID UNIQUEID  \
# 0   RADGRAETZELOGD.34082     34082     GR05
# 1   RADGRAETZELOGD.34083     34083     GR37
# 2   RADGRAETZELOGD.34084     34084     GR08
# 3   RADGRAETZELOGD.34085     34085     GR09
# 4   RADGRAETZELOGD.34086     34086     GR39
# 5   RADGRAETZELOGD.34087     34087     GR40
# 6   RADGRAETZELOGD.34088     34088     GR13
# 7   RADGRAETZELOGD.34089     34089     GR14
# 8   RADGRAETZELOGD.34090     34090     GR15
# 9   RADGRAETZELOGD.34091     34091     GR16
# 10  RADGRAETZELOGD.34092     34092     GR17
# 11  RADGRAETZELOGD.34093     34093     GR18
# 12  RADGRAETZELOGD.34094     34094     GR19
# 13  RADGRAETZELOGD.34095     34095     GR20
# 14  RADGRAETZELOGD.34096     34096     GR22
# 15  RADGRAETZELOGD.34097     34097     GR23
# 16  RADGRAETZELOGD.34098     34098     GR24
# 17  RADGRAETZELOGD.34099     34099     GR25
# 18  RADGRAETZELOGD.34100     34100     GR35
# 19  RADGRAETZELOGD.34101     34101     GR41
# 20  RADGRAETZELOGD.34102     34102     GR42
# 21  RADGRAETZELOGD.34103     34103     GR38
# 22  RADGRAETZELOGD.34104     34104     GR27
# 23  RADGRAETZELOGD.34105     34105     GR36
# 24  RADGRAETZELOGD.34106     34106     GR31
# 25  RADGRAETZELOGD.34077     34077     GR34
# 26  RADGRAETZELOGD.34107     34107     GR29
# 27  RADGRAETZELOGD.34078     34078     GR01
# 28  RADGRAETZELOGD.34108     34108     GR30
# 29  RADGRAETZELOGD.34079     34079     GR02
# 30  RADGRAETZELOGD.34080     34080     GR03
# 31  RADGRAETZELOGD.34081     34081     GR04
# 32  RADGRAETZELOGD.34109     34109     GR32
# 33  RADGRAETZELOGD.34110     34110     GR33
#
#                               BEZEICHNUNG                  ADRESSE   PLZ  \
# 0                                  Stuwer          Stuwerstraße 47  1020
# 1                       Café Schillwasser           Naufahrtweg 14  1220
# 2                               Huberista         Erdbergstraße 22  1030
# 3                                   Karja       Margaretenstraße 2  1040
# 4                              Primetours         Reindorfgasse 25  1150
# 5                               velo.wien         Troststrasse 114  1100
# 6             Fahrradwerkstatt Flickschuh   Hetzendorfer Straße 81  1120
# 7                                 Velobis           Johnstraße 1-3  1140
# 8                               Popsykkel          Reindorfgasse 9  1150
# 9                                    WSEB       Lemböckgasse 53-55  1230
# 10                                   Ursi    Hannah-Arendt-Platz 1  1220
# 11                                  Ferdi    Hannah-Arendt-Platz 1  1220
# 12                       Smarter Together        Quellenstraße 149  1100
# 13                                   3Rad         Erdbergstraße 22  1030
# 14                          Nachbarschaft       Wenckebachgasse 49  1190
# 15                            Familienrad  Maria-Lassnig-Straße 32  1100
# 16                        Bikes and Rails     Emilie-Flöge-Weg 4/3  1100
# 17                         Nordsternmobil        Brünner Straße 27  1210
# 18                 zinc und Caffe vom See    Kettenbrückengasse 17  1050
# 19                          Klub Ensemble        Paletzgasse 22-24  1160
# 20                  Die Schöne Pfuscherei           Kuffnergasse 7  1160
# 21                             Le Bon Mot     Florianigasse 10/3/2  1080
# 22                                  Trude    Hannah-Arendt-Platz 1  1220
# 23                           Wiener Börse          Wallnerstraße 8  1010
# 24                          Lastenexpress  Maria-Lassnig-Straße 34  1100
# 25                               Gersthof           Gentzgasse 160  1180
# 26  Schwerlastanhänger im Sonnwendviertel  Maria-Lassnig-Straße 36  1100
# 27               Kleine Fahrradwerkstatt              Yppenplatz 5  1160
# 28                                Währing     Währinger Straße 122  1180
# 29                                    WUK      Währinger Straße 59  1090
# 30                    Mobilitaetsagentur        Große Sperlgasse 4  1020
# 31                      Reanimated Bikes         Westbahnstraße 35  1070
# 32                       Teenietreff FUX4      Favoritenstrasse 38  1040
# 33                          Kostnix-Laden              Erlgasse 27  1120
#
#                                              WEBLINK1  \
# 0         https://www.graetzlrad.wien/bicycle/stuwer/
# 1   https://www.graetzlrad.wien/bicycle/cafe-schil...
# 2      https://www.graetzlrad.wien/bicycle/huberista/
# 3          https://www.graetzlrad.wien/bicycle/karja/
# 4     https://www.graetzlrad.wien/bicycle/primetours/
# 5           https://www.graetzlrad.wien/bicycle/velo/
# 6     https://www.graetzlrad.wien/bicycle/flickschuh/
# 7        https://www.graetzlrad.wien/bicycle/velobis/
# 8      https://www.graetzlrad.wien/bicycle/popsykkel/
# 9           https://www.graetzlrad.wien/bicycle/wseb/
# 10  https://www.graetzlrad.wien/bicycle/seestadt-a...
# 11  https://www.graetzlrad.wien/bicycle/seestadt-a...
# 12  https://www.graetzlrad.wien/bicycle/smarter-to...
# 13          https://www.graetzlrad.wien/bicycle/3rad/
# 14  https://www.graetzlrad.wien/bicycle/nachbarsch...
# 15   https://www.graetzlrad.wien/bicycle/familienrad/
# 16  https://www.graetzlrad.wien/bicycle/bikes-and-...
# 17  https://www.graetzlrad.wien/bicycle/nordsternm...
# 18          https://www.graetzlrad.wien/bicycle/zinc/
# 19  https://www.graetzlrad.wien/bicycle/klub-ensem...
# 20  https://www.graetzlrad.wien/bicycle/schoene-pf...
# 21    https://www.graetzlrad.wien/bicycle/le-bon-mot/
# 22  https://www.graetzlrad.wien/bicycle/aspern-see...
# 23        https://www.graetzlrad.wien/bicycle/boerse/
# 24  https://www.graetzlrad.wien/bicycle/lastenexpr...
# 25      https://www.graetzlrad.wien/bicycle/gersthof/
# 26  https://www.graetzlrad.wien/bicycle/schwerlast...
# 27  https://www.graetzlrad.wien/bicycle/kleine-fah...
# 28      https://www.graetzlrad.wien/bicycle/waehring/
# 29           https://www.graetzlrad.wien/bicycle/wuk/
# 30  https://www.graetzlrad.wien/bicycle/mobilitaet...
# 31  https://www.graetzlrad.wien/bicycle/reanimated...
# 32  https://www.graetzlrad.wien/bicycle/teenietref...
# 33  https://www.graetzlrad.wien/bicycle/kostnix-la...
#
#                                 TYP  RECHTSWERT_WGS84  HOCHWERT_WGS84  \
# 0                 Christiania Light         16.406865       48.218960
# 1                 Christiania Light         16.457165       48.204519
# 2   Butchers and bicycles MK1 Vario         16.394300       48.201999
# 3             Bakfiets Classic Long         16.366806       48.197745
# 4             Bakfiets Classic Long         16.330169       48.189967
# 5                    Hagen Flagship         16.353729       48.172880
# 6                  Radkutsche Rapid         16.308231       48.167245
# 7                   Dolly Max Drive         16.316322       48.192800
# 8            Larry vs Harry Bullitt         16.330489       48.188383
# 9                Urban Arrow Family         16.309996       48.133641
# 10               Urban Arrow Family         16.501748       48.224035
# 11    Fietsfabriek Bakfiets Classic         16.501611       48.224335
# 12           Bakfiets Classic Short         16.370312       48.175700
# 13                    Nihola Family         16.394578       48.202292
# 14               Urban Arrow Family         16.337429       48.253477
# 15            Bakfiets Classic Long         16.387592       48.179005
# 16                Christiania Light         16.384587       48.181530
# 17                Christiania Event         16.399734       48.261514
# 18            Larry vs Harry Bullit         16.359941       48.195805
# 19           Larry vs Harry Bullitt         16.317892       48.220839
# 20              Bakfiets CargoTrike         16.322752       48.211786
# 21                       Cube Cargo         16.353328       48.212168
